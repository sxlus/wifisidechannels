# %%
from wiki_eve_max.dataset_generator import BFIPWDatasetGenerator
import os 
import pathlib

CWD = os.getcwd()
DSD = pathlib.Path(os.path.join(CWD, "EXPERIMENT"))
X = BFIPWDatasetGenerator(
    folder_in=DSD,
    folder_out="DATASET_TEST"
)
# Out:
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/1/24_09_17-01_02_06_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/10/24_09_17-03_39_38_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/11/24_09_17-03_57_00_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/12/24_09_17-04_14_31_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/13/24_09_17-04_31_47_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/14/24_09_17-04_49_05_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/15/24_09_17-05_06_27_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/16/24_09_17-05_23_47_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/17/24_09_17-05_41_08_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/18/24_09_17-05_58_26_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/19/24_09_17-06_15_47_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/2/24_09_17-01_19_36_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/20/24_09_17-06_33_03_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/21/24_09_17-06_50_25_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/22/24_09_17-07_07_45_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/23/24_09_17-07_25_00_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/3/24_09_17-01_36_56_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/4/24_09_17-01_55_25_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/5/24_09_17-02_12_45_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/6/24_09_17-02_30_10_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/7/24_09_17-02_47_34_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/8/24_09_17-03_04_53_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/9/24_09_17-03_22_17_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/0/24_09_17-16_39_30_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/1/24_09_17-16_56_53_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/10/24_09_17-20_04_11_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/11/24_09_17-20_21_35_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/12/24_09_17-20_39_02_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/13/24_09_17-20_56_59_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/14/24_09_17-21_27_27_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/15/24_09_17-21_44_39_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/16/24_09_17-22_02_45_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/17/24_09_17-22_20_08_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/18/24_09_17-22_37_36_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/19/24_09_17-22_55_13_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/2/24_09_17-17_14_48_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/20/24_09_17-23_12_39_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/21/24_09_17-23_30_54_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/22/24_09_17-23_48_34_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/23/24_09_18-00_05_50_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/3/24_09_17-17_32_54_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/4/24_09_17-17_50_56_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/5/24_09_17-18_08_53_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/6/24_09_17-18_27_20_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/7/24_09_17-18_44_43_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/8/24_09_17-19_25_11_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_1/9/24_09_17-19_42_30_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/0/24_09_18-15_49_34_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/1/24_09_18-15_59_06_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/10/24_09_18-17_24_54_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/11/24_09_18-17_34_23_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/12/24_09_18-17_43_51_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/13/24_09_18-17_53_20_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/14/24_09_18-18_02_50_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/15/24_09_18-18_12_24_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/16/24_09_18-18_21_52_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/17/24_09_18-18_31_17_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/18/24_09_18-18_40_45_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/19/24_09_18-18_50_17_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/2/24_09_18-16_08_38_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/20/24_09_18-18_59_46_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/21/24_09_18-19_09_11_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/22/24_09_18-19_18_44_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/23/24_09_18-19_28_16_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/3/24_09_18-16_18_13_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/4/24_09_18-16_27_46_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/5/24_09_18-16_37_14_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/6/24_09_18-16_46_48_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/7/24_09_18-16_56_19_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/8/24_09_18-17_05_52_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_2/9/24_09_18-17_15_23_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/0/24_09_18-22_27_24_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/1/24_09_18-22_44_43_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/10/24_09_19-01_19_54_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/11/24_09_19-01_37_05_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/12/24_09_19-01_54_17_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/13/24_09_19-02_11_37_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/14/24_09_19-02_28_50_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/15/24_09_19-02_46_07_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/16/24_09_19-03_03_23_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/17/24_09_19-03_20_32_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/18/24_09_19-03_37_40_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/19/24_09_19-03_54_55_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/2/24_09_18-23_02_01_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/20/24_09_19-04_12_08_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/21/24_09_19-04_29_18_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/22/24_09_19-04_46_31_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/23/24_09_19-05_03_42_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/24/24_09_19-05_20_52_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/25/24_09_19-05_38_09_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/26/24_09_19-05_55_20_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/27/24_09_19-06_12_34_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/28/24_09_19-06_29_47_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/29/24_09_19-06_47_00_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/3/24_09_18-23_19_20_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/30/24_09_19-07_04_18_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/31/24_09_19-07_21_23_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/32/24_09_19-07_38_42_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/33/24_09_19-07_55_53_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/34/24_09_19-08_13_09_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/35/24_09_19-08_30_24_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/36/24_09_19-08_47_38_EMSEC_0123456789_meta.dump
# /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_3/37/24_09_19-09_04_50_EMSEC_0123456789_meta.dump

# %%
import numpy as np
from wifisidechannels.models.export_models import Packet

def random_sample(x):
    idx = np.random.randint(0, len(x))
    return x[idx]

def mean_sample_packet(x):
    data = [ y.DATA["V"] for y in x ]
    return Packet(DATA={"V":np.mean(data, axis=0)})

def mean_sample_np(x):
    data = [ y.DATA["V"] for y in x ]
    return np.mean(data, axis=0)

N_SAMPLES       = 128
RANDOM_SPACING  = False
RANDOM_S        = False
PACKET          = False

SPACING = "random_spacing" if RANDOM_SPACING else "even_spacing"
SELECT  = "random_select" if RANDOM_S else "mean"
FUNC    = random_sample if RANDOM_S else mean_sample_packet if PACKET else mean_sample_np
FORMAT  = "PACKET" if PACKET else "NP"

X.create_dataset(
    out_dir=pathlib.Path(os.path.join("DATASETS_TEST", FORMAT, SPACING, SELECT, str(N_SAMPLES))),
    func_on_state=FUNC,
    states_per_transient=N_SAMPLES,
    sample_spacing_random=RANDOM_SPACING,
    v=False,
    vv=False
)
# Out:
# {'domain': 0, 'number_prefix_samples': 500, 'total_states': 289, 'phy_domain': 0, 'train_domain': 0, 'train_delta': 0.2, 'motor_settings': {'ACC_KVAL': 40, 'DEC_KVAL': 40, 'RUN_KVAL': 40, 'HOLD_KVAL': 20, 'MAX_SPEED': 1000, 'FULL_SPEED': 1000, 'ACC': 1000, 'DEC': 1000, 'step_mode': 'FS'}, 'number_of_chunks': 32, 'max_steps': 8000, 'max_positions': 10, 'password_file': PosixPath('/home/localadmin/src/wifisidechannels/PASSWORDS/ONE_PASSWORD_TO_RULE_THEM_ALL.txt'), 'pw': '0123456789', 'interface': 'wlp0s20f3', 'channel': 44, 'mac_sa': '00c0cab63c70', 'mac_da': '80cc9c339049', 'samples_per_state': 48, 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_data.dump', 'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_meta.dump'}
# META:  /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_meta.dump

# %%
import numpy as np
from wifisidechannels.models.export_models import Packet

def random_sample(x):
    idx = np.random.randint(0, len(x))
    return x[idx]

def mean_sample_packet(x):
    data = [ y.DATA["V"] for y in x ]
    return Packet(DATA={"V":np.mean(data, axis=0)})

def mean_sample_np(x):
    data = [ y.DATA["V"] for y in x ]
    return np.mean(data, axis=0)

N_SAMPLES       = 129
RANDOM_SPACING  = False
RANDOM_S        = False
PACKET          = False

SPACING = "random_spacing" if RANDOM_SPACING else "even_spacing"
SELECT  = "random_select" if RANDOM_S else "mean"
FUNC    = random_sample if RANDOM_S else mean_sample_packet if PACKET else mean_sample_np
FORMAT  = "PACKET" if PACKET else "NP"

X.create_dataset(
    out_dir=pathlib.Path(os.path.join("DATASETS_TEST", FORMAT, SPACING, SELECT, str(N_SAMPLES))),
    func_on_state=FUNC,
    states_per_transient=N_SAMPLES,
    sample_spacing_random=RANDOM_SPACING,
    v=False,
    vv=False
)
# Out:
# {'domain': 0, 'number_prefix_samples': 500, 'total_states': 289, 'phy_domain': 0, 'train_domain': 0, 'train_delta': 0.2, 'motor_settings': {'ACC_KVAL': 40, 'DEC_KVAL': 40, 'RUN_KVAL': 40, 'HOLD_KVAL': 20, 'MAX_SPEED': 1000, 'FULL_SPEED': 1000, 'ACC': 1000, 'DEC': 1000, 'step_mode': 'FS'}, 'number_of_chunks': 32, 'max_steps': 8000, 'max_positions': 10, 'password_file': PosixPath('/home/localadmin/src/wifisidechannels/PASSWORDS/ONE_PASSWORD_TO_RULE_THEM_ALL.txt'), 'pw': '0123456789', 'interface': 'wlp0s20f3', 'channel': 44, 'mac_sa': '00c0cab63c70', 'mac_da': '80cc9c339049', 'samples_per_state': 48, 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_data.dump', 'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_meta.dump'}
# META:  /home/localadmin/src/wifisidechannels/EXPERIMENT/ROOM_0/0/24_09_17-00_44_45_EMSEC_0123456789_meta.dump
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 26
#      23 FUNC    = random_sample if RANDOM_S else mean_sample_packet if PACKET else mean_sample_np
#      24 FORMAT  = "PACKET" if PACKET else "NP"
# ---> 26 X.create_dataset(
#      27     out_dir=pathlib.Path(os.path.join("DATASETS_TEST", FORMAT, SPACING, SELECT, str(N_SAMPLES))),
#      28     func_on_state=FUNC,
#      29     states_per_transient=N_SAMPLES,
#      30     sample_spacing_random=RANDOM_SPACING,
#      31     v=False,
#      32     vv=False
#      33 )
#
# File ~/src/wifisidechannels/wiki_eve_max/dataset_generator.py:279, in BFIPWDatasetGenerator.create_dataset(self, meta, out_dir, dataset_meta_file, states_per_transient, func_on_state, sample_spacing_random, v, vv)
#     277     if not data:
#     278         continue
# --> 279     dataset_meta |= self.create_embedded_keystroke_samples(
#     280         data=data,
#     281         meta=meta[phy_domain],
#     282         out_dir=out_dir,
#     283         states_per_transient=states_per_transient,
#     284         func_on_state=func_on_state,
#     285         sample_spacing_random=sample_spacing_random,
#     286         v=v,
#     287         vv=vv
#     288     )
#     289     break
#     290 joblib.dump(dataset_meta, os.path.join(out_dir, dataset_meta_file))
#
# File ~/src/wifisidechannels/wiki_eve_max/dataset_generator.py:218, in BFIPWDatasetGenerator.create_embedded_keystroke_samples(self, data, meta, out_dir, states_per_transient, func_on_state, sample_spacing_random, v, vv)
#     215 if vv: print(len(ts_idx), ts_idx)
#     217 pt_sample = [ func_on_state(data[i*num_samples_per_state:(i+1)*num_samples_per_state]) for i in pt_idx ]
# --> 218 ts_sample = [ func_on_state(data[i*num_samples_per_state:(i+1)*num_samples_per_state]) for i in ts_idx ]
#     220 if vv: print(len(pt_sample), pt_sample)
#     221 if vv: print(len(ts_sample), ts_sample)
#
# Cell In[5], line 14, in mean_sample_np(x)
#      12 def mean_sample_np(x):
#      13     data = [ y.DATA["V"] for y in x ]
# ---> 14     return np.mean(data, axis=0)
#
# File ~/.cache/pypoetry/virtualenvs/wifisidechannels-sEVZrtBk-py3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/wifisidechannels-sEVZrtBk-py3.12/lib/python3.12/site-packages/numpy/core/_methods.py:102, in _mean(a, axis, dtype, out, keepdims, where)
#     101 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
# --> 102     arr = asanyarray(a)
#     104     is_float16_result = False
#     106     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#
# KeyboardInterrupt:

# %%
import joblib
file = "/home/localadmin/src/wifisidechannels/DATASETS_TEST/NP/even_spacing/mean/128/meta.dump"
data = joblib.load(file)

for domain in data.keys():
    print(f"{domain}")
    for target in data[domain].keys():
        print(f"\t{target}: {str(data[domain][target])}")
# Out:
# meta
# 	path: DATASETS_TEST/NP/even_spacing/mean/128
# 	sample_spacing_random: False
# 	states_per_transient: 128
# 0000
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/000.dump', 'pw': '000', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/010.dump', 'pw': '010', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/020.dump', 'pw': '020', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/030.dump', 'pw': '030', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/040.dump', 'pw': '040', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/050.dump', 'pw': '050', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/060.dump', 'pw': '060', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/070.dump', 'pw': '070', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/080.dump', 'pw': '080', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/090.dump', 'pw': '090', 'target': 9}]
# 0001
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/001.dump', 'pw': '001', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/011.dump', 'pw': '011', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/021.dump', 'pw': '021', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/031.dump', 'pw': '031', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/041.dump', 'pw': '041', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/051.dump', 'pw': '051', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/061.dump', 'pw': '061', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/071.dump', 'pw': '071', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/081.dump', 'pw': '081', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/091.dump', 'pw': '091', 'target': 9}]
# 0002
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/002.dump', 'pw': '002', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/012.dump', 'pw': '012', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/022.dump', 'pw': '022', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/032.dump', 'pw': '032', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/042.dump', 'pw': '042', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/052.dump', 'pw': '052', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/062.dump', 'pw': '062', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/072.dump', 'pw': '072', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/082.dump', 'pw': '082', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/092.dump', 'pw': '092', 'target': 9}]
# 0003
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/003.dump', 'pw': '003', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/013.dump', 'pw': '013', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/023.dump', 'pw': '023', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/033.dump', 'pw': '033', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/043.dump', 'pw': '043', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/053.dump', 'pw': '053', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/063.dump', 'pw': '063', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/073.dump', 'pw': '073', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/083.dump', 'pw': '083', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/093.dump', 'pw': '093', 'target': 9}]
# 0004
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/004.dump', 'pw': '004', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/014.dump', 'pw': '014', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/024.dump', 'pw': '024', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/034.dump', 'pw': '034', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/044.dump', 'pw': '044', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/054.dump', 'pw': '054', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/064.dump', 'pw': '064', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/074.dump', 'pw': '074', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/084.dump', 'pw': '084', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/094.dump', 'pw': '094', 'target': 9}]
# 0005
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/005.dump', 'pw': '005', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/015.dump', 'pw': '015', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/025.dump', 'pw': '025', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/035.dump', 'pw': '035', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/045.dump', 'pw': '045', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/055.dump', 'pw': '055', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/065.dump', 'pw': '065', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/075.dump', 'pw': '075', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/085.dump', 'pw': '085', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/095.dump', 'pw': '095', 'target': 9}]
# 0006
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/006.dump', 'pw': '006', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/016.dump', 'pw': '016', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/026.dump', 'pw': '026', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/036.dump', 'pw': '036', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/046.dump', 'pw': '046', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/056.dump', 'pw': '056', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/066.dump', 'pw': '066', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/076.dump', 'pw': '076', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/086.dump', 'pw': '086', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/096.dump', 'pw': '096', 'target': 9}]
# 0007
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/007.dump', 'pw': '007', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/017.dump', 'pw': '017', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/027.dump', 'pw': '027', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/037.dump', 'pw': '037', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/047.dump', 'pw': '047', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/057.dump', 'pw': '057', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/067.dump', 'pw': '067', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/077.dump', 'pw': '077', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/087.dump', 'pw': '087', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/097.dump', 'pw': '097', 'target': 9}]
# 0008
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/008.dump', 'pw': '008', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/018.dump', 'pw': '018', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/028.dump', 'pw': '028', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/038.dump', 'pw': '038', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/048.dump', 'pw': '048', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/058.dump', 'pw': '058', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/068.dump', 'pw': '068', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/078.dump', 'pw': '078', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/088.dump', 'pw': '088', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/098.dump', 'pw': '098', 'target': 9}]
# 0009
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/009.dump', 'pw': '009', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/019.dump', 'pw': '019', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/029.dump', 'pw': '029', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/039.dump', 'pw': '039', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/049.dump', 'pw': '049', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/059.dump', 'pw': '059', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/069.dump', 'pw': '069', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/079.dump', 'pw': '079', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/089.dump', 'pw': '089', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/099.dump', 'pw': '099', 'target': 9}]
# 0010
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/100.dump', 'pw': '100', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/110.dump', 'pw': '110', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/120.dump', 'pw': '120', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/130.dump', 'pw': '130', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/140.dump', 'pw': '140', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/150.dump', 'pw': '150', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/160.dump', 'pw': '160', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/170.dump', 'pw': '170', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/180.dump', 'pw': '180', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/190.dump', 'pw': '190', 'target': 9}]
# 0011
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/101.dump', 'pw': '101', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/111.dump', 'pw': '111', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/121.dump', 'pw': '121', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/131.dump', 'pw': '131', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/141.dump', 'pw': '141', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/151.dump', 'pw': '151', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/161.dump', 'pw': '161', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/171.dump', 'pw': '171', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/181.dump', 'pw': '181', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/191.dump', 'pw': '191', 'target': 9}]
# 0012
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/102.dump', 'pw': '102', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/112.dump', 'pw': '112', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/122.dump', 'pw': '122', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/132.dump', 'pw': '132', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/142.dump', 'pw': '142', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/152.dump', 'pw': '152', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/162.dump', 'pw': '162', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/172.dump', 'pw': '172', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/182.dump', 'pw': '182', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/192.dump', 'pw': '192', 'target': 9}]
# 0013
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/103.dump', 'pw': '103', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/113.dump', 'pw': '113', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/123.dump', 'pw': '123', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/133.dump', 'pw': '133', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/143.dump', 'pw': '143', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/153.dump', 'pw': '153', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/163.dump', 'pw': '163', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/173.dump', 'pw': '173', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/183.dump', 'pw': '183', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/193.dump', 'pw': '193', 'target': 9}]
# 0014
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/104.dump', 'pw': '104', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/114.dump', 'pw': '114', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/124.dump', 'pw': '124', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/134.dump', 'pw': '134', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/144.dump', 'pw': '144', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/154.dump', 'pw': '154', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/164.dump', 'pw': '164', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/174.dump', 'pw': '174', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/184.dump', 'pw': '184', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/194.dump', 'pw': '194', 'target': 9}]
# 0015
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/105.dump', 'pw': '105', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/115.dump', 'pw': '115', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/125.dump', 'pw': '125', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/135.dump', 'pw': '135', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/145.dump', 'pw': '145', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/155.dump', 'pw': '155', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/165.dump', 'pw': '165', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/175.dump', 'pw': '175', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/185.dump', 'pw': '185', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/195.dump', 'pw': '195', 'target': 9}]
# 0016
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/106.dump', 'pw': '106', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/116.dump', 'pw': '116', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/126.dump', 'pw': '126', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/136.dump', 'pw': '136', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/146.dump', 'pw': '146', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/156.dump', 'pw': '156', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/166.dump', 'pw': '166', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/176.dump', 'pw': '176', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/186.dump', 'pw': '186', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/196.dump', 'pw': '196', 'target': 9}]
# 0017
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/107.dump', 'pw': '107', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/117.dump', 'pw': '117', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/127.dump', 'pw': '127', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/137.dump', 'pw': '137', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/147.dump', 'pw': '147', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/157.dump', 'pw': '157', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/167.dump', 'pw': '167', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/177.dump', 'pw': '177', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/187.dump', 'pw': '187', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/197.dump', 'pw': '197', 'target': 9}]
# 0018
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/108.dump', 'pw': '108', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/118.dump', 'pw': '118', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/128.dump', 'pw': '128', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/138.dump', 'pw': '138', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/148.dump', 'pw': '148', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/158.dump', 'pw': '158', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/168.dump', 'pw': '168', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/178.dump', 'pw': '178', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/188.dump', 'pw': '188', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/198.dump', 'pw': '198', 'target': 9}]
# 0019
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/109.dump', 'pw': '109', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/119.dump', 'pw': '119', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/129.dump', 'pw': '129', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/139.dump', 'pw': '139', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/149.dump', 'pw': '149', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/159.dump', 'pw': '159', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/169.dump', 'pw': '169', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/179.dump', 'pw': '179', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/189.dump', 'pw': '189', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/199.dump', 'pw': '199', 'target': 9}]
# 0020
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/200.dump', 'pw': '200', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/210.dump', 'pw': '210', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/220.dump', 'pw': '220', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/230.dump', 'pw': '230', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/240.dump', 'pw': '240', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/250.dump', 'pw': '250', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/260.dump', 'pw': '260', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/270.dump', 'pw': '270', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/280.dump', 'pw': '280', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/290.dump', 'pw': '290', 'target': 9}]
# 0021
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/201.dump', 'pw': '201', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/211.dump', 'pw': '211', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/221.dump', 'pw': '221', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/231.dump', 'pw': '231', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/241.dump', 'pw': '241', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/251.dump', 'pw': '251', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/261.dump', 'pw': '261', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/271.dump', 'pw': '271', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/281.dump', 'pw': '281', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/291.dump', 'pw': '291', 'target': 9}]
# 0022
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/202.dump', 'pw': '202', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/212.dump', 'pw': '212', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/222.dump', 'pw': '222', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/232.dump', 'pw': '232', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/242.dump', 'pw': '242', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/252.dump', 'pw': '252', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/262.dump', 'pw': '262', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/272.dump', 'pw': '272', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/282.dump', 'pw': '282', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/292.dump', 'pw': '292', 'target': 9}]
# 0023
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/203.dump', 'pw': '203', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/213.dump', 'pw': '213', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/223.dump', 'pw': '223', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/233.dump', 'pw': '233', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/243.dump', 'pw': '243', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/253.dump', 'pw': '253', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/263.dump', 'pw': '263', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/273.dump', 'pw': '273', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/283.dump', 'pw': '283', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/293.dump', 'pw': '293', 'target': 9}]
# 0024
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/204.dump', 'pw': '204', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/214.dump', 'pw': '214', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/224.dump', 'pw': '224', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/234.dump', 'pw': '234', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/244.dump', 'pw': '244', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/254.dump', 'pw': '254', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/264.dump', 'pw': '264', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/274.dump', 'pw': '274', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/284.dump', 'pw': '284', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/294.dump', 'pw': '294', 'target': 9}]
# 0025
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/205.dump', 'pw': '205', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/215.dump', 'pw': '215', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/225.dump', 'pw': '225', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/235.dump', 'pw': '235', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/245.dump', 'pw': '245', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/255.dump', 'pw': '255', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/265.dump', 'pw': '265', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/275.dump', 'pw': '275', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/285.dump', 'pw': '285', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/295.dump', 'pw': '295', 'target': 9}]
# 0026
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/206.dump', 'pw': '206', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/216.dump', 'pw': '216', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/226.dump', 'pw': '226', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/236.dump', 'pw': '236', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/246.dump', 'pw': '246', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/256.dump', 'pw': '256', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/266.dump', 'pw': '266', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/276.dump', 'pw': '276', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/286.dump', 'pw': '286', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/296.dump', 'pw': '296', 'target': 9}]
# 0027
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/207.dump', 'pw': '207', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/217.dump', 'pw': '217', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/227.dump', 'pw': '227', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/237.dump', 'pw': '237', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/247.dump', 'pw': '247', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/257.dump', 'pw': '257', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/267.dump', 'pw': '267', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/277.dump', 'pw': '277', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/287.dump', 'pw': '287', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/297.dump', 'pw': '297', 'target': 9}]
# 0028
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/208.dump', 'pw': '208', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/218.dump', 'pw': '218', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/228.dump', 'pw': '228', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/238.dump', 'pw': '238', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/248.dump', 'pw': '248', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/258.dump', 'pw': '258', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/268.dump', 'pw': '268', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/278.dump', 'pw': '278', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/288.dump', 'pw': '288', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/298.dump', 'pw': '298', 'target': 9}]
# 0029
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/209.dump', 'pw': '209', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/219.dump', 'pw': '219', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/229.dump', 'pw': '229', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/239.dump', 'pw': '239', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/249.dump', 'pw': '249', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/259.dump', 'pw': '259', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/269.dump', 'pw': '269', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/279.dump', 'pw': '279', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/289.dump', 'pw': '289', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/299.dump', 'pw': '299', 'target': 9}]
# 0030
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/300.dump', 'pw': '300', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/310.dump', 'pw': '310', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/320.dump', 'pw': '320', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/330.dump', 'pw': '330', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/340.dump', 'pw': '340', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/350.dump', 'pw': '350', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/360.dump', 'pw': '360', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/370.dump', 'pw': '370', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/380.dump', 'pw': '380', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/390.dump', 'pw': '390', 'target': 9}]
# 0031
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/301.dump', 'pw': '301', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/311.dump', 'pw': '311', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/321.dump', 'pw': '321', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/331.dump', 'pw': '331', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/341.dump', 'pw': '341', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/351.dump', 'pw': '351', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/361.dump', 'pw': '361', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/371.dump', 'pw': '371', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/381.dump', 'pw': '381', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/391.dump', 'pw': '391', 'target': 9}]
# 0032
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/302.dump', 'pw': '302', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/312.dump', 'pw': '312', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/322.dump', 'pw': '322', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/332.dump', 'pw': '332', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/342.dump', 'pw': '342', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/352.dump', 'pw': '352', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/362.dump', 'pw': '362', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/372.dump', 'pw': '372', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/382.dump', 'pw': '382', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/392.dump', 'pw': '392', 'target': 9}]
# 0033
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/303.dump', 'pw': '303', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/313.dump', 'pw': '313', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/323.dump', 'pw': '323', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/333.dump', 'pw': '333', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/343.dump', 'pw': '343', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/353.dump', 'pw': '353', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/363.dump', 'pw': '363', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/373.dump', 'pw': '373', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/383.dump', 'pw': '383', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/393.dump', 'pw': '393', 'target': 9}]
# 0034
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/304.dump', 'pw': '304', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/314.dump', 'pw': '314', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/324.dump', 'pw': '324', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/334.dump', 'pw': '334', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/344.dump', 'pw': '344', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/354.dump', 'pw': '354', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/364.dump', 'pw': '364', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/374.dump', 'pw': '374', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/384.dump', 'pw': '384', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/394.dump', 'pw': '394', 'target': 9}]
# 0035
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/305.dump', 'pw': '305', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/315.dump', 'pw': '315', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/325.dump', 'pw': '325', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/335.dump', 'pw': '335', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/345.dump', 'pw': '345', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/355.dump', 'pw': '355', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/365.dump', 'pw': '365', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/375.dump', 'pw': '375', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/385.dump', 'pw': '385', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/395.dump', 'pw': '395', 'target': 9}]
# 0036
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/306.dump', 'pw': '306', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/316.dump', 'pw': '316', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/326.dump', 'pw': '326', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/336.dump', 'pw': '336', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/346.dump', 'pw': '346', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/356.dump', 'pw': '356', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/366.dump', 'pw': '366', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/376.dump', 'pw': '376', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/386.dump', 'pw': '386', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/396.dump', 'pw': '396', 'target': 9}]
# 0037
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/307.dump', 'pw': '307', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/317.dump', 'pw': '317', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/327.dump', 'pw': '327', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/337.dump', 'pw': '337', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/347.dump', 'pw': '347', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/357.dump', 'pw': '357', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/367.dump', 'pw': '367', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/377.dump', 'pw': '377', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/387.dump', 'pw': '387', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/397.dump', 'pw': '397', 'target': 9}]
# 0038
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/308.dump', 'pw': '308', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/318.dump', 'pw': '318', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/328.dump', 'pw': '328', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/338.dump', 'pw': '338', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/348.dump', 'pw': '348', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/358.dump', 'pw': '358', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/368.dump', 'pw': '368', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/378.dump', 'pw': '378', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/388.dump', 'pw': '388', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/398.dump', 'pw': '398', 'target': 9}]
# 0039
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/309.dump', 'pw': '309', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/319.dump', 'pw': '319', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/329.dump', 'pw': '329', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/339.dump', 'pw': '339', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/349.dump', 'pw': '349', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/359.dump', 'pw': '359', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/369.dump', 'pw': '369', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/379.dump', 'pw': '379', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/389.dump', 'pw': '389', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/399.dump', 'pw': '399', 'target': 9}]
# 0040
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/400.dump', 'pw': '400', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/410.dump', 'pw': '410', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/420.dump', 'pw': '420', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/430.dump', 'pw': '430', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/440.dump', 'pw': '440', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/450.dump', 'pw': '450', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/460.dump', 'pw': '460', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/470.dump', 'pw': '470', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/480.dump', 'pw': '480', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/490.dump', 'pw': '490', 'target': 9}]
# 0041
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/401.dump', 'pw': '401', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/411.dump', 'pw': '411', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/421.dump', 'pw': '421', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/431.dump', 'pw': '431', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/441.dump', 'pw': '441', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/451.dump', 'pw': '451', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/461.dump', 'pw': '461', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/471.dump', 'pw': '471', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/481.dump', 'pw': '481', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/491.dump', 'pw': '491', 'target': 9}]
# 0042
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/402.dump', 'pw': '402', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/412.dump', 'pw': '412', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/422.dump', 'pw': '422', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/432.dump', 'pw': '432', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/442.dump', 'pw': '442', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/452.dump', 'pw': '452', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/462.dump', 'pw': '462', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/472.dump', 'pw': '472', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/482.dump', 'pw': '482', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/492.dump', 'pw': '492', 'target': 9}]
# 0043
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/403.dump', 'pw': '403', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/413.dump', 'pw': '413', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/423.dump', 'pw': '423', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/433.dump', 'pw': '433', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/443.dump', 'pw': '443', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/453.dump', 'pw': '453', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/463.dump', 'pw': '463', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/473.dump', 'pw': '473', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/483.dump', 'pw': '483', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/493.dump', 'pw': '493', 'target': 9}]
# 0044
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/404.dump', 'pw': '404', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/414.dump', 'pw': '414', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/424.dump', 'pw': '424', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/434.dump', 'pw': '434', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/444.dump', 'pw': '444', 'target': 4}]
# ...
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/825.dump', 'pw': '825', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/835.dump', 'pw': '835', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/845.dump', 'pw': '845', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/855.dump', 'pw': '855', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/865.dump', 'pw': '865', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/875.dump', 'pw': '875', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/885.dump', 'pw': '885', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/895.dump', 'pw': '895', 'target': 9}]
# 0086
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/806.dump', 'pw': '806', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/816.dump', 'pw': '816', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/826.dump', 'pw': '826', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/836.dump', 'pw': '836', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/846.dump', 'pw': '846', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/856.dump', 'pw': '856', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/866.dump', 'pw': '866', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/876.dump', 'pw': '876', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/886.dump', 'pw': '886', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/896.dump', 'pw': '896', 'target': 9}]
# 0087
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/807.dump', 'pw': '807', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/817.dump', 'pw': '817', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/827.dump', 'pw': '827', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/837.dump', 'pw': '837', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/847.dump', 'pw': '847', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/857.dump', 'pw': '857', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/867.dump', 'pw': '867', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/877.dump', 'pw': '877', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/887.dump', 'pw': '887', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/897.dump', 'pw': '897', 'target': 9}]
# 0088
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/808.dump', 'pw': '808', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/818.dump', 'pw': '818', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/828.dump', 'pw': '828', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/838.dump', 'pw': '838', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/848.dump', 'pw': '848', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/858.dump', 'pw': '858', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/868.dump', 'pw': '868', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/878.dump', 'pw': '878', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/888.dump', 'pw': '888', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/898.dump', 'pw': '898', 'target': 9}]
# 0089
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/809.dump', 'pw': '809', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/819.dump', 'pw': '819', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/829.dump', 'pw': '829', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/839.dump', 'pw': '839', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/849.dump', 'pw': '849', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/859.dump', 'pw': '859', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/869.dump', 'pw': '869', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/879.dump', 'pw': '879', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/889.dump', 'pw': '889', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/899.dump', 'pw': '899', 'target': 9}]
# 0090
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/900.dump', 'pw': '900', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/910.dump', 'pw': '910', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/920.dump', 'pw': '920', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/930.dump', 'pw': '930', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/940.dump', 'pw': '940', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/950.dump', 'pw': '950', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/960.dump', 'pw': '960', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/970.dump', 'pw': '970', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/980.dump', 'pw': '980', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/990.dump', 'pw': '990', 'target': 9}]
# 0091
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/901.dump', 'pw': '901', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/911.dump', 'pw': '911', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/921.dump', 'pw': '921', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/931.dump', 'pw': '931', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/941.dump', 'pw': '941', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/951.dump', 'pw': '951', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/961.dump', 'pw': '961', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/971.dump', 'pw': '971', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/981.dump', 'pw': '981', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/991.dump', 'pw': '991', 'target': 9}]
# 0092
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/902.dump', 'pw': '902', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/912.dump', 'pw': '912', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/922.dump', 'pw': '922', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/932.dump', 'pw': '932', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/942.dump', 'pw': '942', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/952.dump', 'pw': '952', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/962.dump', 'pw': '962', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/972.dump', 'pw': '972', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/982.dump', 'pw': '982', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/992.dump', 'pw': '992', 'target': 9}]
# 0093
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/903.dump', 'pw': '903', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/913.dump', 'pw': '913', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/923.dump', 'pw': '923', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/933.dump', 'pw': '933', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/943.dump', 'pw': '943', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/953.dump', 'pw': '953', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/963.dump', 'pw': '963', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/973.dump', 'pw': '973', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/983.dump', 'pw': '983', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/993.dump', 'pw': '993', 'target': 9}]
# 0094
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/904.dump', 'pw': '904', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/914.dump', 'pw': '914', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/924.dump', 'pw': '924', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/934.dump', 'pw': '934', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/944.dump', 'pw': '944', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/954.dump', 'pw': '954', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/964.dump', 'pw': '964', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/974.dump', 'pw': '974', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/984.dump', 'pw': '984', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/994.dump', 'pw': '994', 'target': 9}]
# 0095
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/905.dump', 'pw': '905', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/915.dump', 'pw': '915', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/925.dump', 'pw': '925', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/935.dump', 'pw': '935', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/945.dump', 'pw': '945', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/955.dump', 'pw': '955', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/965.dump', 'pw': '965', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/975.dump', 'pw': '975', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/985.dump', 'pw': '985', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/995.dump', 'pw': '995', 'target': 9}]
# 0096
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/906.dump', 'pw': '906', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/916.dump', 'pw': '916', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/926.dump', 'pw': '926', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/936.dump', 'pw': '936', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/946.dump', 'pw': '946', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/956.dump', 'pw': '956', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/966.dump', 'pw': '966', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/976.dump', 'pw': '976', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/986.dump', 'pw': '986', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/996.dump', 'pw': '996', 'target': 9}]
# 0097
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/907.dump', 'pw': '907', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/917.dump', 'pw': '917', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/927.dump', 'pw': '927', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/937.dump', 'pw': '937', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/947.dump', 'pw': '947', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/957.dump', 'pw': '957', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/967.dump', 'pw': '967', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/977.dump', 'pw': '977', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/987.dump', 'pw': '987', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/997.dump', 'pw': '997', 'target': 9}]
# 0098
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/908.dump', 'pw': '908', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/918.dump', 'pw': '918', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/928.dump', 'pw': '928', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/938.dump', 'pw': '938', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/948.dump', 'pw': '948', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/958.dump', 'pw': '958', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/968.dump', 'pw': '968', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/978.dump', 'pw': '978', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/988.dump', 'pw': '988', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/998.dump', 'pw': '998', 'target': 9}]
# 0099
# 	0: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/909.dump', 'pw': '909', 'target': 0}]
# 	1: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/919.dump', 'pw': '919', 'target': 1}]
# 	2: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/929.dump', 'pw': '929', 'target': 2}]
# 	3: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/939.dump', 'pw': '939', 'target': 3}]
# 	4: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/949.dump', 'pw': '949', 'target': 4}]
# 	5: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/959.dump', 'pw': '959', 'target': 5}]
# 	6: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/969.dump', 'pw': '969', 'target': 6}]
# 	7: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/979.dump', 'pw': '979', 'target': 7}]
# 	8: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/989.dump', 'pw': '989', 'target': 8}]
# 	9: [{'data_file': 'DATASETS_TEST/NP/even_spacing/mean/128/ROOM_0/00/999.dump', 'pw': '999', 'target': 9}]
