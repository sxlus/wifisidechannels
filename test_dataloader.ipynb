# %%
from wiki_eve_max.dataset import BFIKEYSTROKE
import os

CWD = os.getcwd()
DSD = os.path.join(CWD, "EXPERIMENT", "WILDE_13_8samples_16posptransient")
data_loader = BFIKEYSTROKE(
    folders=[
        DSD
    ],
    access={
        "domain": "train_domain",
        "class": "current_pw",
        "data_file": "data_file"
    })

for x in data_loader.m_log["DATA"].keys():
    for y in data_loader.m_log["DATA"][x].keys():
        print("\n", x, y, len(data_loader.m_log["DATA"][x][y]), data_loader.m_log["DATA"][x][y])
        for d in data_loader.m_log["DATA"][x][y]:
            for key in d.keys():
                print("\t", key, d[key])
                break
#print(data_loader.m_log["DATA"])
# Out:
#  0 0 20 [{'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13_8samples_16posptransient/24_09_13-15_44_32_WILDE_13_000_meta.dump', 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13/24_09_13-15_44_32_WILDE_13_000_data.dump'}, {'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13_8samples_16posptransient/24_09_13-15_45_14_WILDE_13_001_meta.dump', 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13/24_09_13-15_45_14_WILDE_13_001_data.dump'}, {'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13_8samples_16posptransient/24_09_13-15_46_04_WILDE_13_002_meta.dump', 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13/24_09_13-15_46_04_WILDE_13_002_data.dump'}, {'meta_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13_8samples_16posptransient/24_09_13-15_46_54_WILDE_13_003_meta.dump', 'data_file': '/home/localadmin/src/wifisidechannels/EXPERIMENT/WILDE_13/24_09
# ...
